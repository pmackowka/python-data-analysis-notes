# %% [markdown]
# Pobieranie danych z serii po indeksie liczbowym: pojedynczy element (`pok[73]`), lista indeksów (`pok[[64,73,575]]`) oraz wycinek (`pok[2:10]`, `pok[795:]`).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
pok = pd.read_csv('/content/pokemon.csv', usecols=['Name'], squeeze=True)

# %%
pok[73]
# Out:
# 'Machoke'

# %%
# pok[64,73,575] Będzie error

pok[[64,73,575]]
# Out:
# 64     Arcanine
# 73      Machoke
# 575    Simipour
# Name: Name, dtype: object

# %%
pok[2:10]
# Out:
# 2                     Venusaur
# 3        VenusaurMega Venusaur
# 4                   Charmander
# 5                   Charmeleon
# 6                    Charizard
# 7    CharizardMega Charizard X
# 8    CharizardMega Charizard Y
# 9                     Squirtle
# Name: Name, dtype: object

# %%
pok[795:]
# Out:
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
# Name: Name, dtype: object

# %%
pok[795:800]
# Out:
# 795                Diancie
# 796    DiancieMega Diancie
# 797    HoopaHoopa Confined
# 798     HoopaHoopa Unbound
# 799              Volcanion
# Name: Name, dtype: object

# %%
pok[:4]
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# Name: Name, dtype: object

# %%
pok[-2:]
# Out:
# 798    HoopaHoopa Unbound
# 799             Volcanion
# Name: Name, dtype: object

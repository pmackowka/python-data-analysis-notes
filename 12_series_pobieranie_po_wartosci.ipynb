# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %% [markdown]
# Obecnie powinno się korzystać z loc & iloc
#
# Pozostałe zostały przedstawione jeśli ktoś kiedyś użył w kodzie innej metody.

# %% [markdown]
# Dostęp do wartości po etykiecie indeksu (`s['b']`) oraz bezpieczniejsza metoda `s.get()`, która — w odróżnieniu od indeksowania nawiasowego — nie rzuca wyjątku, gdy etykieta nie istnieje, tylko zwraca `None` (lub wartość domyślną).

# %%
index = ['a', 'b', 'c', 'd', 'e', 'e']
values = ['Austria', 'Belgium', 'Canada', 'Denmark', 'England', 'Estonia']
s = pd.Series(values,index)
s
# Out:
# a    Austria
# b    Belgium
# c     Canada
# d    Denmark
# e    England
# e    Estonia
# dtype: object

# %%
s['b']
# Out:
# 'Belgium'

# %%
s['e']
# Out:
# e    England
# e    Estonia
# dtype: object

# %%
s.get('b')
# Out:
# 'Belgium'

# %%
s.get('e')
# Out:
# e    England
# e    Estonia
# dtype: object

# %%
# s.at[1] error

# %%
s.at['b']
# Out:
# 'Belgium'

# %%
s.at['e']
# Out:
# e    England
# e    Estonia
# dtype: object

# %%
s.iat[1]
# Out:
# 'Belgium'

# %%
# s.iat['b'] error

# %%
# s.loc[1] error

# %%
s.loc['b']
# Out:
# 'Belgium'

# %%
s.loc['e']
# Out:
# e    England
# e    Estonia
# dtype: object

# %%
s.iloc[1]
# Out:
# 'Belgium'

# %%
# s.iloc['b'] error

# %%
s.iloc[[0,1]]
# Out:
# a    Austria
# b    Belgium
# dtype: object

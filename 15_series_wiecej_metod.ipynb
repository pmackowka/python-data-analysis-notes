# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %% [markdown]
# Metody statystyczne na serii: `count()`, `sum()`, `mean()`, `median()`, `std()`, `min()`/`max()` oraz `idxmin()`/`idxmax()` (zwracające etykietę, przy której występuje wartość minimalna/maksymalna), a `value_counts()` pokazuje częstość wystąpień unikalnych wartości.

# %%
pok = pd.read_csv('/content/pokemon.csv', usecols=['Name','Attack'], squeeze=True,index_col='Name')
pok.head()
# Out:
# Name
# Bulbasaur                 49
# Ivysaur                   62
# Venusaur                  82
# VenusaurMega Venusaur    100
# Charmander                52
# Name: Attack, dtype: int64

# %%
pok.count()
# Out:
# 800

# %%
pokType = pd.read_csv('/content/pokemon.csv', usecols=['Name','Type 2'], squeeze=True,index_col='Name')
pokType.head()
# Out:
# Name
# Bulbasaur                Poison
# Ivysaur                  Poison
# Venusaur                 Poison
# VenusaurMega Venusaur    Poison
# Charmander                  NaN
# Name: Type 2, dtype: object

# %%
pokType.value_counts()
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Rock        14
# Ice         14
# Ghost       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
pok.min()
# Out:
# 5

# %%
pok.max()
# Out:
# 190

# %%
# To nazwa pok z siłą ataku 5

pok.idxmin()
# Out:
# 'Chansey'

# %%
pok.loc[pok.idxmin()]
# Out:
# 5

# %%
pok.idxmax()
# Out:
# 'MewtwoMega Mewtwo X'

# %%
pok.loc[pok.idxmax()]
# Out:
# 190

# %%
pok.mean()
# Out:
# 79.00125

# %%
pok.sum() / pok.count()
# Out:
# 79.00125

# %%
pok.median()
# Out:
# 75.0

# %%
pok.std()
# Out:
# 32.45736586949843
